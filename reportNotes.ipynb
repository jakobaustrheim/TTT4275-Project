# %% [markdown]
# ## Gauss

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import chi2

x = np.linspace(0, 10, 500) 
v = 3 

y = chi2.pdf(x, df=v)

plt.plot(x, y)
plt.show()
